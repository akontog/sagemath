# %% [markdown]
# <div style="padding: 20px 0; text-align: center; font-weight: bold; font-size: 170%; background-color: #1d4055; color: #ffffff;"> 01. Εισαγωγή</div>

# %% [markdown]
# # Ιστορικά στοιχεία

# %% [markdown]
# Το 2005, ο Αμερικανός μαθηματικός William Stein ξεκίνησε το Sage με στόχο την παραγωγή δωρεάν λογισμικού για μαθηματικούς υπολογισμούς. Με το Sage να καλύπτει μια μακροχρόνια ανάγκη των μαθηματικών, σύντομα μια διεθνής κοινότητα εκατοντάδων προγραμματιστών σχηματίστηκε γύρω από αυτό. Αρχικά υπήρχε κάποια έμφαση στη θεωρία αριθμών, το πεδίο ενδιαφέροντος του ιδρυτή του, καθώς όμως οι συνεισφορές αυξάνονταν, οι δυνατότητές του επεκτάθηκαν προοδευτικά σε πολλούς τομείς των μαθηματικών. Αυτό, σε συνδυασμό με τις αριθμητικές δυνατότητες που προσέφερε το οικοσύστημα της επιστημονικής Python, έκανε το Sage το γενικού σκοπού μαθηματικό λογισμικό που είναι σήμερα. Είναι ελεύθερο λογισμικό με τους συγγραφείς να μην επιβάλλουν κανέναν περιορισμό στη χρήση, αναδιανομή, μελέτη ή τροποποίησή του. Αρκεί, μόνο, οι τροποποιήσεις να παραμείνουν επίσης ελεύθερες.

# %% [markdown]
# # Οδηγίες εκτέλεσης

# %% [markdown]
# Το μόνο που έχετε να κάνετε για να εκτελέσετε εντολές του Sage είναι να επισκεφτείτε την διεύθυνση https://sagecell.sagemath.org/, να πληκτρολογήστε την πρώτη σας εντολή, για παράδειγμα μία αριθμητική πράξη και να κάνετε click στο evaluate.

# %%
5+4

# %% [markdown]
# Εναλλακτικά ο υπολογισμός γίνεται και με Shift+Enter.

# %% [markdown]
# Οι παρούσες σημειώσεις έχουν δημιουργηθεί με το jupyter notebook.

# %% [markdown]
# # Τελεστές Operators

# %% [markdown]
# Το Sage μπορεί να χρησιμοποιηθεί σαν μία αριθμομηχανή με τις εκφράσεις να μπορούν να γίνουν όσο πολύπλοκες θέλουμε.

# %%
(7+5)*(9-6)+8-2

# %% [markdown]
# Παρατηρούμε ότι η πράξη του πολλαπλασιασμού τίθεται με το σύμβολο `*`, της διαίρεσης με το `/` και σε περίπτωση που θέλουμε διαφορετική προτεραιότητα από την εξορισμού χρησιμοποιούμε αντίστοιχες παρενθέσεις. Η προτεραιότητα είναι αυτή που περιμένουμε από τα μαθηματικά και βλέπουμε στον επόμενο πίνακα.

# %% [markdown]
# | Τελεστής  | Προσεταιριστικότητα | Πράξη |
# |:---------:|:------------:|:-------:|
# | `**` ή `^` | ← | ύψωση σε δύναμη (`2**3 = 8`) |
# | `*`, `/`, `//`, `%`  | → | Πολλαπλασιασμός, Διαίρεση, Ακέραια Διαίρεση, Υπόλοιπο (`2*3 = 6`, `6/2 = 3`, `5//2 = 2`, `5%2 = 1`) |
# | `+`, `-` | → | Πρόσθεση, Αφαίρεση (`2 + 3 = 5`, `5 - 2 = 3`) |

# %% [markdown]
# Η προσεταιριστικότητα (ή αλλιώς associativity) αναφέρεται στο πώς ομαδοποιούνται οι πράξεις όταν υπάρχουν πολλαπλοί τελεστές του ίδιου τύπου. Ειδικά για τον τελεστή της δύναμης (`**` ή `^`), είναι αριστερή (←), δηλαδή, οι πράξεις ομαδοποιούνται από τα δεξιά προς τα αριστερά.
#
# Στο επόμενο παράδειγμα, πρώτα θα υπολογιστεί η δεξιά δύναμη, `3^2 = 9` και έπειτα η `2^9=512`.

# %%
2^3^2

# %% [markdown]
# Προφανώς αν επιθμούμε διαφορετική σειρά εκτέλεσης πράξεων κάνουμε χρήση παρενθέσεων.

# %%
(2^3)^2

# %% [markdown]
# ---
# **Παράδειγμα**
#
# Έστω ότι καταθέτουμε ένα ποσό 1000 ευρώ στην τράπεζα με ετήσιο επιτόκιο 1.5% και θέλουμε να υπολογίσουμε το ποσό μετά από 20 χρόνια. Ο τύπος που μας δίνει το τελικό ποσό:
#
# $$
#     A = P \left(1 + r\right)^{t}
# $$
#
# όπου:
#
# - A είναι το τελικό ποσό,
#
# - P είναι το αρχικό κεφάλαιο,
#
# - r είναι το ετήσιο επιτόκιο (σε δεκαδική μορφή),
#
# - t είναι ο χρόνος σε έτη.
# </div>

# %%
1000*(1+0.015)^20

# %% [markdown]
# Υποστηρίζονται τρεις τελεστές διαίρεσης:
#
# - `/` Διαίρεση που επιστρέφει πραγματικό ή ρητό αποτέλεσμα
#
# - `//` Ακέραια διαίρεση, υποχρεωτικά μεταξύ ακεραίων
#
# - `%` Υπόλοιπο διαίρεσης

# %%
5/2, 5//2, 5%2

# %% [markdown]
# Για να επιστραφεί πραγματικός αριθμός στην πράξη 5/2 θα πρέπει
#
# - είτε τουλάχιστον ένας από τους τελεστέους να είναι πραγματικός
#
# - είτε να γίνει χρήση της συνάρτησης αριθμητικής προσέγγισης που αναφέρεται στη συνέχεια.

# %%
5/2.0

# %% [markdown]
# ---
# **Παράδειγμα**
#
# Έστω ότι θέλουμε να υπολογίσουμε την τιμή της επόμενης συνάρτησης για x=5.
#
# $$ f(x) = \frac{(x - 2)^4}{4 + (x + 3)^3} $$

# %% [markdown]
# Παρατηρούμε ότι όσο σύνθετη και να γίνει η παράσταση, δεν χρησιμοποιούμε αγκύλες, `(5 - 2)^4 / [4 + (5 + 3)^3]` αλλά διαδοχικές παρενθέσεις. Επιπλέον, βλέπουμε ότι το Sage, επειδή το αποτέλεσμα δεν είναι ακέραιο, αλλά οι τελεστέοι είναι, δεν εμφανίζει την αριθμητική τιμή αλλά το κλάσμα `27/172`.

# %%
(5 - 2)^4 / (4 + (5 + 3)^3)

# %% [markdown]
# # show

# %% [markdown]
# Για να εμφανίσει με "όμορφο" τρόπο το αποτέλεσμα παρέχεται η συνάρτηση `show()`.

# %%
show((5 - 2)^4 / (4 + (5 + 3)^3))

# %% [markdown]
# # Αριθμητική προσέγγιση n()

# %% [markdown]
# Εάν επιθυμούμε την αριθμητική τιμή, στις περιπτώσεις που οι τελεστέοι είναι ακέραιοι, θα πρέπει να κάνουμε χρήση της `N()` (ή `n()` ή `numerical_approx()`) που χρησιμοποιείται για να προσεγγίσει αριθμητικά μία έκφραση.

# %%
N((5 - 2)^4 / (4 + (5 + 3)^3))

# %% [markdown]
# Η προαιρετική παράμετρος `digits` θέτει τον αριθμό των σημαντικών ψηφίων που θα εμφανιστούν.

# %%
N((5 - 2)^4 / (4 + (5 + 3)^3),digits=5)

# %% [markdown]
# # built-in σταθερές

# %% [markdown]
# Πολύ συχνή είναι η χρήση στα μαθηματικά των σταθερών **π** και **e**. Η πρώτη είναι ενσωματωμένη ως `pi` και η δεύτερη ως `e`.

# %%
N(pi)

# %%
N(e,digits=10)

# %% [markdown]
# Άλλες σταθερές είναι η χρυσή τομή, `golden_ratio` και η φανταστική μονάδα, `i`.

# %%
n(golden_ratio)

# %%
N(i),N(sqrt(-1))

# %% [markdown]
# # built-in συναρτήσεις

# %% [markdown]
# Το Sage παρέχει μία σειρά από λογαριθμικές, εκθετικές, τριγωνομετρικές συναρτήσεις.

# %% [markdown]
# ## Ρίζες

# %% [markdown]
# Η συνάρτηση sqrt μας επιστρέφει την τετραγωνική ρίζα ενός αριθμού.

# %%
sqrt(225)

# %% [markdown]
# Σε περίπτωση, όμως, ακέραιας παραμέτρου, το αποτέλεσμα που επιστρέφεται από το SageMath είναι επίσης ακέραιο.

# %%
sqrt(12)

# %% [markdown]
# Εάν επιθυμούμε δεκαδικό αριθμό κάνουμε χρήση της `n()`.

# %%
n(sqrt(12))

# %% [markdown]
# Σημειώνεται ότι στην περίπτωση που ο αριθμός είναι ήδη δεκαδικός, δεν είναι απαραίτητη η χρήση της `n()`.

# %%
sqrt(12.0)

# %% [markdown]
# Αν επιθυμούμε ρίζες μεγαλύτερης τάξης μπορεί να γίνει κατάλληλη χρήση του τελεστή `**` ή `^`.

# %%
1024^(1/10)

# %% [markdown]
# Κάνοντας χρήση της παραμέτρου `all` και τιμής της `True` μπορούμε να πάρουμε και την αρνητική ρίζα του αριθμού.

# %%
sqrt(4,all=True)

# %% [markdown]
# Εφόσον ο αριθμός είναι αρνητικός οι ρίζες μας θα είναι μιγαδικες.

# %%
sqrt(-4,all=True)

# %% [markdown]
# Τα αποτελέσματα στις παραπάνω περιπτώσεις βρίσκονται ανάμεσα σε `[]` που υποδεικνύουν λίστα. Οι λίστες θα συζητηθούν αργότερα.

# %% [markdown]
# ## Λογάριθμοι

# %% [markdown]
# Κάνοντας χρήση την συνάρτησης `log` μπορούν να υπολογιστούν οι λογάριθμοι στο Sage. Ο φυσικός λογάριθμος, με βάση το `e` υπολογίζεται εξορισμού χωρίς την χρήση άλλης παραμέτρου.

# %%
N(log(325))

# %% [markdown]
# Σε περίπτωση που επιθυμούμε λογάριθμο άλλης βάσης θα πρέπει να χρησιμοποιηθεί και 2η παράμετρος, `base`, πέρα από τον αριθμό.

# %%
log(1024,base=2)

# %% [markdown]
# ---
#
# **Παράδειγμα**
#
# Έστω ότι στο παραπάνω παράδειγμα που καταθέσαμε 1000 ευρώ στην τράπεζα με ετήσιο επιτόκιο 1.5% θέλουμε να υπολογίσουμε σε πόσα χρόνια το ποσό θα διπλασιαστεί
#
# Τύπος:
# $$ A = P \left(1 + r\right)^{t} $$
#
# Επίλυση:
#
# Αντικαθιστούμε τις τιμές:
# $$ 2000 = 1000 \left(1 + 0.015\right)^{t} $$
#
# Απλοποιούμε:
# $$ 2 = \left(1.015\right)^{t} $$
#
# Λογάριθμος:
# $$ \log(2) = t \cdot \log(1.015)$$
#
# Λύνοντας για t:
# $$ t = \frac{\log(2)}{\log(1.015)} $$

# %%
N(log(2)/log(1.015))

# %% [markdown]
# Το ποσό θα διπλασιαστεί σε 47 χρόνια.

# %% [markdown]
# ## Τριγωνομετρικές συναρτήσεις

# %% [markdown]
# Οι τριγωνομετρικές συναρτήσεις στο Sage είναι αυτές που θα περιμέναμε, `sin` για ημίτονο, `cos` για συνημίτονο κ.ο.κ. Κάτι που θα πρέπει να προσέξουμε είναι ότι οι παράμετροι είναι σε ακτίνια.
#
# Υπενθυμίζεται ότι:
# $$
# \text{degrees} = \text{radians} \times \frac{180}{\pi}
# $$

# %%
pi/3*(180/pi) # π/3 ακτίνια = 60 μοίρες

# %%
sin(pi/3)

# %% [markdown]
# Παρατηρούμε ότι και εδώ το Sage μας δίνει ακριβείς απαντήσεις αντί για αριθμητικές προσεγγίσεις, κάτι που μερικές φορές μπορεί να μην μας βολεύει. Στις περιπτώσεις αυτές χρησιμοποιούμε την συνάρτηση `n()`.

# %%
cos(pi/12)

# %%
n(cos(pi/12))

# %% [markdown]
# Ακολουθεί πίνακας με γνωστές τριγωνομετρικές συναρτήσεις όπως καλούνται στο Sage.

# %% [markdown]
# | Συνάρτηση          | Περιγραφή                            | Σημείωση                                              |
# |--------------------|--------------------------------------|-------------------------------------------------------|
# | **Βασικές**|
# `sin(x)`           | Ημίτονο                             |  |
# | `cos(x)`           | Συνημίτονο                          |        |
# | `tan(x)`           | Εφαπτομένη                          |$$ \tan(x) = \frac{\sin(x)}{\cos(x)} $$|
# | **Δευτερεύουσες**|
# | `csc(x)`           | Συντέμνουσα                         | $$ \csc(x) = \frac{1}{\sin(x)} $$                     |
# | `sec(x)`           | Τέμνουσα                       | $$ \sec(x) = \frac{1}{\cos(x)} $$                     |
# | `cot(x)`           | Συνέφαπτομένη                       | $$ \cot(x) = \frac{1}{\tan(x)} $$                     |
# | **Αντίστροφες**|
# | `arcsin(x)` ή  `asin(x)`       | Τόξο ημιτόνου     | Ορίζεται για $$ x \in [-1, 1] $$                      |
# | `arccos(x)` ή   `acos(x)`     | Τόξο συνημιτόνου | Ορίζεται για $$ x \in [-1, 1] $$                      |
# | `arctan(x)` ή  `atan(x)`     | Τόξο εφαπτομένης | Ορίζεται για όλες τις πραγματικές τιμές του x      |
# | `arccsc(x)`        | Τόξο συντέμνουσας               | Ορίζεται για $$ x \in (-\infty, -1] \cup [1, \infty) $$|
# | `arcsec(x)`        | Τόξο τέμνουσας            | Ορίζεται για $$ x \in (-\infty, -1] \cup [1, \infty) $$|
# | `arccot(x)`        | Αντίστροφη συνέφαπτομένη            | Ορίζεται για όλες τις πραγματικές τιμές του x      |

# %% [markdown]
# ---
# **Παράδειγμα**
#
# Υπολογίστε το εμβαδόν ενός τριγώνου γνωρίζοντας ότι οι δύο πλευρές του είναι a = 5 και b = 7 και η γωνία που σχηματίζουν είναι
# $$ \theta = \frac{\pi}{6} $$
#
# Χρησιμοποιήστε τον τύπο του ημιτόνου για να βρείτε το εμβαδόν: $$ A = \frac{1}{2}ab\sin(\theta) $$

# %%
(1/2) * 5 * 7 * sin(pi/6)

# %% [markdown]
# # Μεταβλητές

# %% [markdown]
# Το SageMath υποστηρίζει την αποθήκευση τιμών διαφόρων τύπων σε απλές μεταβλητές όπως αυτές που υποστηρίζονται σε οποιαδήποτε γλώσσα προγραμματισμού. Επιπλέον, παρέχει τη δυνατότητα δημιουργίας συμβολικών μεταβλητών για συμβολικούς υπολογισμούς.

# %% [markdown]
# ## Απλές μεταβλητές

# %% [markdown]
# Για να αποθηκευτεί το αποτέλεσμα ενός υπολογισμού, χρησιμοποιείται μία μεταβλητή και ο τελεστής ανάθεσης `=`.

# %%
a = 5 + 2

# %% [markdown]
# Στη συνέχεια η αποθηκευμένη τιμή μπορεί να επαναχρησιμοποιηθεί.

# %%
a

# %%
(a+3)*a

# %% [markdown]
# Όταν ένας υπολογισμός αποθηκεύεται σε μία μεταβλητή, δεν εμφανίζεται στην οθόνη. Για να εκτυπωθεί πρέπει να γίνει το εξής:

# %%
b = 2*a;b

# %% [markdown]
# Σε γενικές γραμμές η χρήση του `;` επιτρέπει την ύπαρξη πολλών εντολών στην ίδια γραμμή.

# %%
a=3;b=2;a,b

# %% [markdown]
# Οι μεταβλητές θα συζητηθούν περαιτέρω στην ενότητα του προγραμματισμού.

# %% [markdown]
# ## Συμβολικές μεταβλητές

# %% [markdown]
# Μια συμβολική έκφραση στο SageMath είναι κάθε αλγεβρική ή μαθηματική έκφραση που περιλαμβάνει μεταβλητές, αριθμούς και λειτουργίες που δεν έχουν αναγκαστικά συγκεκριμένες τιμές από την αρχή, σε αντίθεση με τις απλές μεταβλητές. Οι συμβολικές μεταβλητές θα πρέπει να δηλωθούν με τον επόμενο τρόπο πριν χρησιμοποιηθούν. Το SR, που σημαίνει Symbolic Ring, δεν είναι υποχρεωτικό και στις περισσότερες περιπτώσεις θα παραλείπεται.

# %% [markdown]
# Στην συνέχεια ορίζεται το `w` ώς συμβολική μεταβλητή. Πρέπει να σημειωθεί ότι η `x`, καθώς και σε πολλά περιβάλλοντα οι `y`, `z`, είναι εξορισμού συμβολικές χωρίς να απαιτείται να δηλωθεί από εμάς.

# %%
w = SR.var('w')
show(w**2 + 5)

# %%
f = (w^2 - 1) / (w - 1);show(f)

# %% [markdown]
# ## Επαναχρησιμοποίηση αποτελεσμάτων

# %% [markdown]
# Πέρα από την χρήση μεταβλητών, προηγούμενα αποτελέσματα μπορούν να επαναχρησιμοποιηθούν με τις ενσωματωμένες μεταβλητές `_`, `__`, `___`. Αυτές οι μεταβλητές αναφέρονται στα αποτελέσματα των τελευταίων υπολογισμών. Οι μεταβλητές αυτές είναι βολικές για επαναχρησιμοποίηση αλλά για πολύπλοκα προγράμματα είναι προτιμότερη η αποθήκευση σε απλές μεταβλητές.

# %%
sin(pi/6)

# %%
_+1

# %%
(_ + __) *2

# %%
___/_

# %% [markdown]
# # Είσοδος, Έξοδος

# %% [markdown]
# ## input

# %% [markdown]
# Η συνάρτηση `input` χρησιμοποιείται για την είσοδο δεδομένων από τον χρήστη. Εξορισμού λαμβάνεται μία συμβολοσειρά, `str` και σε πολλές περιπτώσεις θα πρέπει αυτή να μετατραπεί σε πραγματικό ή ακέραιο.

# %%
name = input('Πώς σε λένε;')
'Γειά σου '+name

# %%
x = input("Δώσε έναν αριθμό: ")
x = float(x)
'Η τετραγωνική ρίζα του '+str(x)+' είναι '+str(sqrt(x))

# %% [markdown]
# Προσοχή θα πρέπει να δοθεί στην είσοδο του χρήστη. Υπάρχει περίπτωση, για παράδειγμα, να ζητηθεί αριθμός αλλά ο χρήστης να δώσει  συμβολοσειρά. Στην περίπτωση αυτή θα προκύψει `ValueError` και το πρόγραμμα θα τερματίσει αντικανονικά. Θα πρέπει να γίνει χειρισμός αυτών των πιθανών λαθών από τον προγραμματιστή.

# %% [markdown]
# Η εντολή input() δεν υποστηρίζεται στο περιβάλλον του Sage Cell.

# %% [markdown]
# ## print

# %% [markdown]
# Βασική συνάρτηση εξόδου αποτελεί η `print`. Μπορεί να εμφανίζει διαδοχικές τιμές χωριζωντάς τες μεταξύ τους με `,`.

# %%
x = 3;y = 5
res = x + y
print (x,'+',y,'=',res)

# %% [markdown]
# Υπάρχει η δυνατότητα εκτέλεσης πράξεων και απευθείας εμφάνισης τους σε μία `print`.

# %%
a=3;b=8
print(a,'*',b,'=',a*b)

# %% [markdown]
# Εξορισμού, η εμφάνση μίας `print` τελειώνει με αλλαγή γραμμής, κάτι που μπορεί να αλλάξει με την παράμετρο `end`. Στα επόμενα παραδείγμα γίνεται χρήση της επαναληπτικής δομής `for` και την `range`. Θα συζητηθούν σε επόμενη ενότητα.

# %%
for i in range(10): print(i,end=" ")

# %%
for i in range(5,105,5): print(i,end=" + ")

# %% [markdown]
# Η παράμετρος `sep` καθορίζει πώς θα χωρίζονται μεταξύ τους τα διαφορετικά αντικείμενα εκτύπωσης που χωρίζονται με `,`. Αν δεν τεθεί χωρίονται με κενό.

# %%
print('Το', 2, 'εις την', 3, 'είναι:', 2 ** 3, sep="|")

# %% [markdown]
# ---
# **Παράδειγμα**
#
# Δίνεται η συνάρτηση
# $$
# f(x) = x^2 + 2x + 1
# $$
# Υπολογίστε την τιμή της για τιμή που δίνεται από τον χρήστη.
#
# **Προσοχή**: Η f_x είναι μία απλή μεταβλητή που παίρνει απλά την τιμή μίας έκφρασης και όχι συμβολική συνάρτηση του SagMath

# %%
# Λήψη τιμής από τον χρήστη
x = input("Δώσε μια τιμή για το x: ")
# Μετατροπή της εισόδου σε πραγματικό αριθμό
x = float(x)
# Υπολογισμός της συνάρτησης f(x) = x^2 + 2x + 1 στο x
f_x = x^2 + 2*x + 1
# Εκτύπωση του αποτελέσματος
print('f(',x,')=',f_x,sep='')

# %% [markdown]
# # Σχόλια

# %% [markdown]
# Στο SageMath, όπως και σε όλες τις γλώσσες προγραμματισμού, τα σχόλια χρησιμοποιούνται για να εξηγήσουν τμήματα του κώδικα ή να αφήσουν σημειώσεις, χωρίς αυτά να επηρεάζουν την εκτέλεση του προγράμματος. Βοηθούν στο να διατηρείται ο κώδικας ευανάγνωστος και κατανοητός και αγνοούνται από τον διερμηνευτή κατά την εκτέλεση του.

# %% [markdown]
# Τα σχόλια μίας γραμμής ξεκινούν με `#`

# %%
# Αυτό είναι ένα σχόλιο
show(5 / 3) # και αυτό είναι σχόλιο

# %% [markdown]
# Μπορούμε να έχουμε και σχόλια πολλών γραμμών που ξεκινούν και τελειώνουν με `'''` ή `"""`. Αυτά έχουν χρήση σε συναρτήσεις η αντικείμενα που θα συζητηθούν στην ενότητα του προγραμματισμού.

# %%
"""
Αυτό είναι ένα σχόλιο πολλών γραμμών.
Προηγείται της δήλωσης μίας συνάρτησης.
Ο διερμηνευτής δεν θα εμφανίσει τίποτα.
"""
def f(x):
    return x^2

# %% [markdown]
# # Βοήθεια

# %% [markdown]
# Καθε εντολή ή συνάρτηση στο Sage έχει και την αντίστοιχη τεκμηρίωση που μας δίνεται αν μετά το όνομά της προσθέσουμε ένα `?`. Επιπλέον, στο περιβάλλον του jupyter εάν πληκτρολογήσουμε κάποιους χαρακτήρες και στην συνέχεια το tab στο πληκτρολόγιο εμφανίζονται οι συναρτήσεις που ξεκινούν από τους χαρακτήρες αυτούς. Βοήθεια παρέχεται και στο βασικό μενού Help του jupyter.

# %%
sin?

# %% [markdown]
# Στην περίπτωση που δεν είμαστε σίγουροι για το όνομα της εντολής έχουμε την δυνατότητα να κάνουμε χρήση του χαρακτήρα "μπαλαντερ" `*`. Έτσι για παράδειγμα αν πιστεύουμε ότι ξεκινά από si θα γράψουμε `si*?` ενώ αν νομίζουμε ότι τελειώνει σε si, `*si?`. Στη συνέχεια αναζητούμε όλες τις εντολές που περιέχουν το si οπυδήποτε.

# %%
*si*?
