# %% [markdown]
# <div style="padding: 20px 0; text-align: center; font-weight: bold; font-size: 170%; background-color: #1d4055; color: #ffffff;"> Εργαστήριο 02. Γραφικές παραστάσεις</div>

# %% [markdown]
# # Άσκηση, εμφάνιση, διάστημα

# %% [markdown]
# Σχεδιάστε την γραφική παράσταση των επόμενων συναρτήσεων σε ένα γράφημα.
#
# Οι συναρτήσεις είναι:
# $$
#         f(x) = x^2, g(x) = x^3, h(x) = 2x^2
# $$
#
# Κάθε γραφική παράσταση θα πρέπει να:
#
# - έχει το δικός της στυλ, `linestyle`
#
# - το δικό της χρώμα `color`
#
# - το δικό της πάχος `thickness`
#
#
# Το γράφημα να σχεδιαστεί με 2 τρόπους.
#
# - Προσθέτοντας τα επιμέρους plots
#
# - Κάνοντας χρήση λιστών. Σημείωση η παράμετρος `thickness` δεν τίθεται με λίστα, θα πρέπει όλες οι συναρτήσεις να έχουν το ίδιο πάχος.

# %%
# Δήλωση Συναρτήσεων

# %%
# 1ος τρόπος, προσθέτοντας τα plots

# %%
# 2ος τρόπος: με χρήση λιστών

# %% [markdown]
# # Άσκηση συνάρτηση, παράγωγος, σημείο

# %% [markdown]
# Έστω συνάρτηση
#
# $$
# f(x) = x^3 - 3x^2 + 2x
# $$
#
# Σχεδιάστε:
#
# - την καμπύλη της συνάρτησης στο (-1,3)
#
# - το σημείο (2,f(2))
#
# - κείμενο που να δείχνει το σημείο.
#
# - την εφαπτομένη της στο σημείο.
#
# Σημειώσεις:
#
# - Η εφαπτομένη της g(x) στο  (2,f(2)) δίνεται, ως γνωστόν, από τον τύπο:
# $$
# y - f(x_0)=f'(x_0)(x-x_0)
# $$
# Και με παράγωγο:
# $$
# f'(x) = 3x^2-6x+2, f'(2) = 2
# $$
# Άρα
# $$
# g(x) = 2x-4
# $$
# - Χρησιμοποιήστε `gridlines` `minor` και διαφορετικά χρώματα.

# %% [markdown]
# Σημειώνεται ότι οι παράγωγοι μπορούν να υπολογιστούν αυτόματα από το Sage. Θα γίνει εκτενέστερη αναφορά στην επόμενη ενότητα.

# %%
f(x) = x^3 - 3*x^2 + 2*x
fprime = diff(f)
show(fprime)
show(fprime(2))

# %% [markdown]
# # Άσκηση, σχήματα, σημεία

# %% [markdown]
# Σχεδίασε ένα γεωμετρικό σχήμα που να περιέχει:
#
# - Έναν κύκλο με ακτίνα 2 και κέντρο την αρχή των αξόνων.
#
# - Κείμενο στα σημεία A = (0, 0), B = (2, 0), C = (0, 2), D = (-2, 0)
#
# - Ένα τρίγωνο με κορυφές: (-2,0), (2,0), (0,2)
#
# - Έναν δίσκο που είναι γεμισμένος με χρώμα Με κέντρο την αρχή των αξόνων και ακτίνα 0.5.
#
# - Δύο βέλη που δείχνουν από το κέντρο του κύκλου προς το σημείο (2,0) και προς το (0,1)
#
# - Πρόσθεσε υπόμνημα που να δείχνει κατάλληλο κείμενο για κάθε σχήμα, για παράδειγμα Τρίγωνο, Βέλος 1, Βέλος 2.
#
# - Οι άξονες να μην φαίνονται.

# %% [markdown]
# # Άσκηση, απεικόνιση ολοκληρώματος

# %% [markdown]
# Δημιουργήστε τη γραφική παράσταση
# $$
# f(x) = \sqrt{x}
# $$
# η οποία θα είναι σκιασμένη στο χωρίο που μας ενδιαφέρει για το επόμενο ολοκλήρωμα.
# $$
# \int_0^2 \sqrt{x} \, dx
# $$
# Επιπλέον, το ολοκλήρωμα θα φαίνεται σαν κείμενο στο γράφημα.
# Σημείωση: Σε latex θα χρειαστούμε:
#
# - `\int`: Το σύμβολο του ολοκληρώματος
#
# - `_a^b`: Τα όρια ολοκλήρωσης. Το κατώτερο όριο είναι a και το ανώτερο όριο είναι b
#
# - `\sqrt{x}`: Η ρίζα του x

# %% [markdown]
# # Άσκηση, γέμισμα

# %% [markdown]
# Δίνεται η συνάρτηση
# $$
# f(x) = \sin(x)
# $$
# και η συνάρτηση
# $$
# g(x) = \cos(x+\frac{\pi}{2})
# $$
#
# 1. Σχεδιάστε τις γραφικές παραστάσεις των δύο συναρτήσεων στο διάστημα  [-2π, 2π].
#
# 2. Γεμίστε την περιοχή μεταξύ των δύο συναρτήσεων στο διάστημα [-π, π] με ένα χρώμα της επιλογής σας.
#
# 3. Γράψτε κείμενο στα σημεία (-2π,0), (-π,0), (0,0), (π,0), (2π,0),
#
# Σημείωση: Στην ενότητα του λογισμού θα δούμε πώς βρίσκουμε τα σημεία τομής συναρτήσεων.

# %% [markdown]
# # Άσκηση Τρίγωνο

# %% [markdown]
# Δίνονται οι κορυφές του τριγώνου: A(0,0), B(1,2), C(3,1).
# Σχεδιάστε το τρίγωνο με κορυφές τα σημεία Α, Β, C
# Βρείτε και σχεδιάστε τις τρεις διαμέσους του τριγώνου, χρησιμοποιώντας τον τύπο για το μέσο μεταξύ δύο σημείων A(a,b), B(c,d):
# $$
# M(x,y) = \left( \frac{a+c}{2}, \frac{b+d}{2} \right)
# $$
# Χρησιμοποιήστε διαφορετικό χρώμα για κάθε διάμεσο. Μπορείτε να σχεδιάσετε όλα τα σημεία αλλά και κείμενο για κάθε ένα από αυτά.
#
# Σημειώνεται ότι αν ένα σημείο, έστω B έχει τεθεί B = (1,2), για πάρουμε το x και το y του θα πρέπει να ορίσουμε B[0] και B[1] αντίστοιχα.

# %% [markdown]
# # Άσκηση, Πολικές συντεταγμένες

# %% [markdown]
# α) Στον επόμενο κώδικα θέστε διάφορες τιμές στα e και d έτσι ώστε να πετύχετε να σχεδιάσετε κάθε κωνική τομή. Τι καμπύλες παίρνετε για e<1, e=1 και e>1;

# %%
var("theta")
e = 1/3
d = 3
polar_plot(e*d/(1-e*cos(theta)), (theta, 0, 2*pi))

# %% [markdown]
# β) Στον επόμενο κώδικα θέστε διάφορες τιμές στα a και k. Επίσης αλλάξτε από cos σε sin ή θέστε την μεταβλητή διάφορες τιμές όπως π/4 κ.ο.κ.

# %%
var("theta")
a = 2
k = 4
d = 0
polar_plot(a*cos(k*theta+d), (theta, 0, 2*pi))

# %% [markdown]
# # Άσκηση, Πεπλεγμένες συναρτήσεις

# %% [markdown]
# Με τη βοήθεια της `implicit_plot` σχεδιάστε μία έλλειψη της οποίας το μήκος είναι διπλάσιο του ύψους. Με την βοήθεια της παραμέτρου `aspect_ratio` κάντε την έλλειψη να φαίνεται σαν κύκλος.
# Υπενθύμιση:
#
# Εξίσωση έλλειψης:
# $$
# \frac{x^2}{\alpha ^{2}}+{\frac {y^{2}}{\beta ^{2}}}=1
# $$
#
# Σχεδιάστε την ίδια έλλειψη με την `polar_plot`. Εξίσωση έλλειψης σε πολικές συντεταγμένες:
# $$
# \frac{a b}{\sqrt{(b \cos(\theta))^2 + (a \sin(\theta))^2}}
# $$

# %% [markdown]
# Στον επόμενο κώδικα χρησιμοποιείται η συνάρτηση `parametric_plot` που χρησιμοποιείται όταν η καμπύλη έχει παρασταθεί παραμετρικά. Έτσι για παράδειγμα ο τύπος ενός κύκλου θα είναι:
# $$
# x(t) = cos(t), y(t) = sin(t)
# $$
# Αν θέσουμε διαφορετικές παραμέτρους a και b δημιουργούμε ελλειψοειδή:
# $$
# x(t) = α\cos{(t)}, y(t) = b\sin{(t)}
# $$
# Πειραματιστείτε με τις τιμές a και b στο επόμενο παράδειγμα.

# %%
var('t')
a=1
b=1
parametric_plot((a*cos(t), b*sin(t)), (t, 0, 2*pi))

# %% [markdown]
# Η _rose curve_ που σχεδιάστηκε στο μάθημα με polar_plot μπορεί να σχεδιαστεί και με `parametric_plot` βασισμένοι στους τύπους:
# $$
# x(t) = \cos(kt)\cos(t), \quad y(t) = \cos(kt)\sin(t)
# $$
# Πειραματιστείτε με την τιμή k.

# %%
k = 4
parametric_plot((cos(k*t)*cos(t), cos(k*t)*sin(t)), (t, 0, 2*pi), color='purple', title='Rose Curve')

# %% [markdown]
# # Άσκηση, Τρισδιάστατα γραφικά

# %% [markdown]
# Δίνεται η συνάρτηση:
# $$
# f(x, y) = \sqrt{x^2 + y^2}
# $$
# Σχεδιάστε την 3D γραφική παράσταση της συνάρτησης f(x,y) στο διάστημα x,y∈[−2,2].

# %% [markdown]
# # Άσκηση, Density, contour

# %% [markdown]
# Συνδυάστε κατάλληλα τις `density_plot` και `contour_plot` για να αποδώσετε τις παραβολικές καμπύλες που προκύπτουν από την συνάρτηση:
# $$
# f(x, y) = x^2 - y^2
# $$
