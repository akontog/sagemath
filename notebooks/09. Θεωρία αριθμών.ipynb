# %% [markdown]
# <div style="padding: 20px 0; text-align: center; font-weight: bold; font-size: 170%; background-color: #1d4055; color: #ffffff;"> 09. Θεωρία αριθμών</div>

# %% [markdown]
# # Παραγοντοποίηση

# %% [markdown]
# # Αριθμητική Υπολοίπων
