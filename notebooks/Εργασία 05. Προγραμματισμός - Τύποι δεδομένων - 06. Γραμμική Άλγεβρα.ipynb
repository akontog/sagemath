# %% [markdown]
# <div style="padding: 20px 0; text-align: center; font-weight: bold; font-size: 170%; background-color: #1d4055; color: #ffffff;"> Εργασία 05. Προγραμματισμός - Τύποι δεδομένων 06. Γραμμική Άλγεβρα</div>

# %% [markdown]
# # Σχήματα με *

# %% [markdown]
# Με την βοήθεια των τελεστών `+` και `*` ή εμφώλευσης σχεδιάστε με σύμβολα *:
#
# 1. Μία αντίστροφη πυραμίδα ύψους _height_.
#
# 2. Ένα κενό στη μέση τετράγωνο πλαίσιο μεγέθους _size_ με γεμάτες όμως διαγωνίους.

# %%
# 1.

# %%
# 2.

# %% [markdown]
# # Γράφημα με λίστα

# %% [markdown]
# α) Δημιουργήστε ένα γράφημα για x [0,1] και y [0,1] που να περιλαμβάνει όλες τις επόμενες συναρτήσεις.
#
# 1. $x^{20}$
#
# 2. $x^{5}$
#
# 3. $x^{4}$
#
# 4. $x^{3}$
#
# 5. $x^{2}$
#
# 6. $x^{1}$
#
# 7. $x^{\frac{1}{2}}$
#
# 8. $x^{\frac{1}{3}}$
#
# 9. $x^{\frac{1}{4}}$
#
# 10. $x^{\frac{1}{5}}$
#
# 11. $x^{\frac{1}{20}}$
#
# Για να το πετύχετε θα εισάγετε τις συναρτήσεις σε λίστα. Μπορείτε να χρησιμοποιήσετε την λίστα _powers_ που περιέχει όλες τις παραπάνω δυνάμεις και την τεχνική list comprehension για να δημιουργήσετε την λίστα συναρτήσεων.

# %%
powers = [20, 5, 4, 3, 2, 1, 1/2, 1/3, 1/4, 1/5, 1/20]

# %% [markdown]
# β) Με την βοήθεια της `srange` και list comprehension κάντε πιο "πυκνές" τις συναρτήσεις στο γράφημα σχεδιάζοντας τις $x^2$, $x^4$, ..., $x^20$ και $x^{\frac{1}{2}}$, $x^{\frac{1}{4}}$, ... $x^{\frac{1}{20}}$

# %%
# α)

# %%
# β)

# %% [markdown]
# # Tuple, απόσταση, μέσο

# %% [markdown]
# Για τρισδιάστατα σημεία $A=(x_1,y_1,z_1)$ και $B=(x_2,y_2,,z_2)$ η απόσταση δίνεται από τον τύπο:
# $$
# d = \sqrt{(x_2 - x_1)^2 + (y_2 - y_1)^2 + (z_2 - z_1)^2}
# $$
#
# Το μέσο σημείο:
# $$
# M = \left( \frac{x_1 + x_2}{2}, \frac{y_1 + y_2}{2}, \frac{z_1 + z_2}{2} \right)
# $$
#
# 1. Βρείτε την απόσταση και το μέσο των σημείων A = (1, 2, 3) και B = (4, 5, 6).
#
# 2. Σχεδιάστε γραφική παράσταση των σημείων A, B, M και του ευθύγραμμου τμήματος AB με την βοήθεια των `point3d`, `line3d`.

# %% [markdown]
# # Solve λεξικό

# %% [markdown]
# Βρείτε τα κοινά σημεία των συναρτήσεων $f(x) = x^3 - 6x^2 + 11x - 6$ και  $g(x) = 2x - 4$ και σχεδιάστε τα σε γραφική παράσταση στην οποία θα απεικονίζονται και οι συναρτήσεις. Χρησιμοποιήστε λεξικό σε συνδυασμό με την `solve`.

# %% [markdown]
# # Γραμμικοί μετασχηματισμοί, παραμόρφωση σχήματος

# %% [markdown]
# Δημιουργήστε ένα σχήμα, για παράδειγμα ένα καράβι, με γραμμές από μία λίστα με δυάδες σημείων και στη συνέχεια χρησιμοποιήστε γραμμικό μετασχηματισμό της αρεσκείας σας για να το παραμορφώσετε.

# %% [markdown]
# # Σύστημα εξισώσεων

# %% [markdown]
# Έστω το σύστημα εξισώσεων:
#
# $$
# \begin{cases}
# 5x + y = 5 \\
# 2x - y = 1
# \end{cases}
# $$
# Δείξτε γραφικά την λύση και στην συνέχεια λύστε το σύστημα με τους επόμενους τρόπους.
#
# 1. Χρήση της `solve`
#
# 2. Μέθοδος Αντίστροφου Πίνακα
#
# 3. Αριθμητική προσέγγιση

# %%
# γραφική αναπαράσταση

# %%
# 1.

# %%
# 2.

# %%
# 3
