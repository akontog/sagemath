# %% [markdown]
# <div style="padding: 20px 0; text-align: center; font-weight: bold; font-size: 170%; background-color: #1d4055; color: #ffffff;"> Εξετάσεις
# </div>

# %% [markdown]
# # Άσκηση 1

# %% [markdown]
# _(Μονάδες 2)_ Έστω η συνάρτηση $f(x) = x^2 \sin\left(\frac{1}{x}\right), \quad x \neq 0$.
#
# 1. **Έλεγχος συνέχειας**:
#    - Υπολογίστε το όριο της συνάρτησης $f(x)$ στο σημείο $x = 0$.
#
#    - Δημιουργήστε μια κατάλληλη κλαδική συνάρτηση $g(x)$ ώστε να διασφαλίσετε την συνέχεια στο $x = 0$.
#
# 2. **Υπολογισμός παραγώγου**: Βρείτε την παράγωγο $g'(x)$. Ειδικά για $x = 0$ χρησιμοποιήστε τον ορισμό της παραγώγου για να επιβεβαίωσετε το αποτέλεσμά σας.
#
# 3. **Άνω και κάτω φράγματα**: Σχεδιάστε το γράφημα της συνάρτησης $f(x)$ μαζί με τις συναρτήσεις $y = x^2$ και $y = -x^2$ στο [-0.01,0.01], την f(x) με μπλε χρώμα και τις συναρτήσεις $x^2$ και $-x^2$ με πράσινες διακεκομμένες γραμμές. Διαπιστώστε ότι η συνάρτηση ικανοποιεί την ανισότητα:  $-x^2 \leq f(x) \leq x^2$ για τιμές του x κοντά στο 0.

# %% [markdown]
# # 'Ασκηση 2

# %% [markdown]
# _(Μονάδες 2)_ Έστω συναρτήσεις $f(x) = 0.5x^3 - x^2 - x + 1$ και $g(x) = x$.
#
# 1.  Παραστήστε γραφικά τις συναρτήσεις για το διάστημα $x \in [-2, 4]$.
#
# 2. Βρείτε τα τοπικά ακρότατα της f(x). Προσδιορίστε αν είναι τοπικά μέγιστα ή ελάχιστα με χρήση της $f''(x)$.
#
# 3. Βρείτε όλα τα σημεία τομής των δύο συναρτήσεων, δηλαδή τα x για τα οποία ισχύει f(x)=g(x). Για να το επιτύχετε επιλύστε προσεγγιστικά με κατάλληλη χρήση της `find_root`.
#
# 4. Υπολογίστε το εμβαδόν του χωρίου που βρίσκεται ανάμεσα στις δύο συναρτήσεις για το διάστημα που καθορίζεται από τα δύο μικρότερα σημεία τομής.
#
# 5. Στην γραφική παράσταση προσθέστε με γραμμοσκίαση το χωρίο για το οποίο υπολογίστηκε το εμβαδόν. Τέλος, φροντίστε να φαίνονται τα σημεία τομής και τα ακρότατα.

# %% [markdown]
# # Άσκηση 3

# %% [markdown]
# _(Μονάδες 1.5)_ Το πρώτο πρόγραμμα υπολογιστή που γράφτηκε ποτέ, γραμμένο από την Ada Lovelace (Άντα Λάβλεϊς), υπολόγιζε τους αριθμούς Bernoulli
#
# Ο αναδρομικός τύπος υπολογισμού τους είναι:
# $$
# B_n = -\frac{\sum_{k=0}^{n-1} \binom{n+1}{k} B_k} {n+1}, \quad \text{για } n \geq 1, \quad B_0 = 1.
# $$
#
# 1. Υλοποιήστε μία μέθοδο python, έστω _myBernoulli_ η οποία δέχεται τον αριθμό n και υπολογίζει αναδρομικά τον n-οστο αριθμό Bernoulli.
#
# 2. Εμφανίστε τους 10 πρώτους αριθμούς Bernoulli όπως προκύπτει από την κλήση της αναδρομικής σας μεθόδου. Επιπλέον καλέστε κατάλληλα την μέθοδο `bernoulli` του Sage για να τους εμφανίσετε ξανά, επαληθεύοντας έτσι και την ορθότητα της μεθόδου σας.
#
# 3. Κάντε χρήση της `list_plot` για να απεικονίσετε κατάλληλα τους αριθμούς που βρήκατε.
#
# Στο SageMath, η συνάρτηση `binomial(n, k)` υπολογίζει το:
#
# $$
# \binom{n}{k} = \frac{n!}{k!(n-k)!}
# $$

# %% [markdown]
# # Άσκηση 4

# %% [markdown]
# _(Μονάδες 1.5)_ Γράψετε ένα πρόγραμμα στη SageMath που θα σχεδιάζει:
#
# - Ένα καρτεσιανό πλέγμα σε ένα ορθογώνιο σύστημα συντεταγμένων, με γραμμές που εκτείνονται από -25 έως 25 στον άξονα x και στον άξονα y.
#
# - Έναν κύκλο με ακτίνα 20 και κέντρο στο σημείο (0,0), σχεδιασμένο με πράσινο χρώμα και πάχος γραμμής 4.
#
# - Σημεία τομής των γραμμών του πλέγματος που βρίσκονται στο εσωτερικό του κύκλου, σχεδιασμένα με μπλε χρώμα και μέγεθος 20.

# %% [markdown]
# # Άσκηση 5

# %% [markdown]
# _(Μονάδες 2)_ Σε έναν πίνακα m×n μονοψήφιων αριθμών, μπορούμε να συνδυάσουμε ένα ή περισσότερα ψηφία που βρίσκονται σε οποιαδήποτε οριζόντια, κάθετη ή διαγώνια γραμμή σε οποιαδήποτε κατεύθυνση για να προκύψουν νέοι αριθμοί.
#
# Παράδειγμα: Για τον πίνακα
# $$
# \begin{bmatrix}
# 1 & 3 \\
# 4 & 7
# \end{bmatrix}
# $$ μπορούμε να πάρουμε τους αριθμούς 1, 3, 4, 7, 13, 14, 17, 31, 34, 37, 41, 43, 47, 74, 73, 71. Από τους αριθμούς αυτούς, μας ενδιαφέρουν μόνο οι πρώτοι αριθμοί, δηλαδή οι: 3, 7, 13, 17, 31, 37, 41, 43, 47, 71, 73.
#
# Στις 29 Απριλίου 1999, ο Wilfred Whiteside από το Χιούστον του Τέξας, ανακάλυψε έναν πίνακα 7 επί 7 στον οποίο μπορούν να βρεθούν, με τον παραπάνω τρόπο, 281 τέτοιοι πρώτοι.
# $$
# \begin{bmatrix}
# 3 & 1 & \mathbf{3} & \mathbf{7} & \mathbf{3} & 3 & 9 \\
# 9 & 9 & 2 & 3 & 3 & 3 & 3 \\
# 6 & 9 & \mathbf{7} & 7 & 8 & 9 & 4 \\
# 7 & 6 & 1 & \mathbf{5} & 9 & 1 & 9 \\
# 7 & 7 & 3 & 4 & \mathbf{2} & 1 & 1 \\
# 9 & 9 & 4 & 7 & 9 & \mathbf{3} & 9 \\
# 3 & 3 & 7 & 1 & 9 & 9 & \mathbf{9}
# \end{bmatrix}
# $$
# Έχουν σημανθεί με εντονότερα ψηφία δύο τέτοιοι πρώτοι αριθμοί, ο 75239 διαγώνια και ο 373 στην πρώτη γραμμή.
#
# 1. Για τον πίνακα αυτόν βρείτε και εμφανίστε:
#
#     - Το ίχνος του
#
#     - την ορίζουσα
#
#     - τις ιδιοτιμές του πίνακα
#
# 2. Υλοποιήστε μια μέθοδο _extractSequences_ που δέχεται έναν τετραγωνικό πίνακα Matrix και εξάγει όλες τις γραμμές και στήλες (Δεν απαιτείται η εξαγωγή των διαγώνιων) από αριστερά προς τα δεξιά αλλά και αντίστροφα. Για παράδειγμα, για τον πίνακα:
# $$
# \begin{bmatrix}
# 1 & 1 & 3 \\
# 7 & 5 & 4 \\
# 9 & 3 & 7
# \end{bmatrix}
# $$
# θα πρέπει να επιστρέψει: [(1, 1, 3), (3, 1, 1), (7, 5, 4), (4, 5, 7), (9, 3, 7), (7, 3, 9), (1, 7, 9), (9, 7, 1), (1, 5, 3), (3, 5, 1), (3, 4, 7), (7, 4, 3)]
#
# 3. Υλοποιήστε μία μέθοδο Python _checkPrime_ η οποία δέχεται ως παράμετρο ένα σύνολο _foundprimes_ και ένα tuple _numbers_ και προσθέτει στο σύνολο _foundprimes_ όλους τους πρώτους που θα βρει στη λίστα συνενώνοντας κατάλληλα τους αριθμούς από τα αριστερά προς τα δεξιά.
#
# Για παράδειγμα για το: (1, 3, 4, 7, 8 ) θα πρέπει να επιστρέψει: {3, 7, 13, 47, 347}
#
# 4. Καλέστε κατάλληλα τις παραπάνω μεθόδους ώστε για τον πίνακα του Wilfred Whiteside να βρείτε πόσοι πρώτοι υπάρχουν. Σημειώνεται ότι επειδή δεν ελέγχονται οι διαγώνιες των πινάκων, το αποτέλεσμα θα είναι μόνο 205 πρώτοι.

# %% [markdown]
# # Άσκηση 6

# %% [markdown]
# _(Μονάδες 1)_ Έστω δίκαιο ζάρι με 6 πλευρές, αριθμημένες από το 1 έως το 6.
#
# 1. Δημιουργήστε 100 προσομοιώσεις κατά τις οποίες ρίχνουμε 1000 φορές το ζάρι σε κάθε προσμοίωση και υπολογίζουμε το άθροισμα των αριθμών που προκύπτουν από τις ρίψεις.
#
# 2. Δημιουργήστε ένα ιστόγραμμα που δείχνει την κατανομή των αθροισμάτων.
