# %% [markdown]
# <div style="padding: 20px 0; text-align: center; font-weight: bold; font-size: 170%; background-color: #1d4055; color: #ffffff;"> Εργαστήριο 01. Εισαγωγή </div>

# %% [markdown]
# # Τελεστές Operators

# %% [markdown]
# ## Άσκηση

# %% [markdown]
# Υπολογίστε και συγκρίνετε:
#
# 1. Τις ημέρες σε έναν αιώνα (χωρίς δίσεκτα έτη)
#
# 2. Τα λεπτά σε μία ημέρα
#
# 3. Τα δευτερόλεπτα σε μία εβδομάδα
#
# 4. Τις ώρες σε έναν μήνα (υποθέτοντας 30 ημέρες ανά μήνα)

# %%
daysPerCentury = 365 * 100
minutesPerDay = 24 * 60
secondsPerWeek = 7 * 24 * 60 * 60
hoursPerMonth = 30 * 24
daysPerCentury, minutesPerDay, secondsPerWeek, hoursPerMonth
# Out:
# (36500, 1440, 604800, 720)

# %% [markdown]
# ## Άσκηση

# %% [markdown]
# Υπολογίστε τη δύναμη
#
# $$ {3^{2^3}} $$

# %%
3^2^3
# Out:
# 6561

# %% [markdown]
# ## Άσκηση

# %% [markdown]
# Υπολογίστε και εμφανίστε το ακέραιο πηλίκο, το υπόλοιπο, το πηλίκο ως πραγματικό αριθμό και το πηλίκο ως ρητό των αριθμών 28 και 10.

# %%
28//10, 28%10, N(28/10), 28/10
# Out:
# (2, 8, 2.80000000000000, 14/5)

# %% [markdown]
# # built-in σταθερές, συναρτήσεις

# %% [markdown]
# ## Άσκηση

# %% [markdown]
# Χρησιμοποιήστε κατάλληλα τελεστές, σταθερές, παρενθέσεις και συναρτήσεις του SageMath για να υπολογίσετε τις τιμές των επόμενων παραστάσεων.
#
# 1. $$ \frac{5 + 2}{3 \times (3^2 + 5)} $$
#
# 1. $$ (3 + 2) \times (2 + 4) \times 3^2 $$
#
# 1. $$ \cos\left(\frac{\pi}{3}\right) + \sin\left(\frac{\pi}{6}\right) $$
#
# 1. $$ \sin(30^\circ) + \tan(60^\circ) $$
#
# 1. $$ \log_2(512) + \ln(1) $$
#
# 1. $$ \ln(e^2) + \log_{10}(100) $$
#
# 1. $$ e^{\sin(\frac{\pi}{2})} + \ln(2 + 2) $$
#
# 1. $$ \tan(\frac{\pi}{6}) \times \ln(2 \times e) + \cos(90^\circ) $$

# %%
# 1.
(5 + 2) / (3 * (3^2 + 5))
# Out:
# 1/6

# %%
# 2.
(3 + 2) * (2 + 4) * 3^2
# Out:
# 270

# %%
# 3.
cos(pi/3) + sin(pi/6)
# Out:
# 1

# %%
# 4. 
sin(30 * pi/180) + tan(60 * pi/180)
# Out:
# sqrt(3) + 1/2

# %%
# 5.
log(512, 2) + log(1)
# Out:
# 9

# %%
# 6. 
log(e^2) + log(100, 10)
# Out:
# 4

# %%
# 7. 
exp(sin(pi/2)) + log(2 + 2)
# Out:
# e + 2*log(2)

# %%
# 8. 
tan(pi/6) * log(2 * e) + cos(90 * pi/180)
# Out:
# 1/3*sqrt(3)*log(2*e)

# %% [markdown]
# # Μεταβλητές

# %% [markdown]
# ## Άσκηση

# %% [markdown]
# Στο ημιτελές τμήμα κώδικα που ακολουθεί έχουν τεθεί οι απλές μεταβλητές a, b με τιμή 3 και 4 αντίστοιχα. Συνεχίστε τον κώδικα ώστε στο τέλος το a να έχει την τιμή 4 και το b την τιμή 3.

# %%
a = 3
b = 4

# %%
temp = a
a = b
b = temp
# εναλλακτικά 
#a,b = b,a
a,b
# Out:
# (4, 3)

# %% [markdown]
# ## Άσκηση

# %% [markdown]
# Με κατάλληλη χρήση συμβολικών μεταβλητών ορίστε τις επόμενες συναρτήσεις
#
# $$
# f(x) = \frac{(x^2 + 3x + 2) \cdot (x - 1)}{x^2 - 4x + 3} + \frac{3x^3}{x^2 + x + 1} - \sin(x)
# $$
#
# $$
# g(x,y) = \frac{(x + y)^2 - (x - y)^2}{x \cdot y + 1} + \frac{x^3 - y^3}{x - y} + 2 \cdot \sin(xy)
# $$
#
# Εμφανίσε τις συναρτήσεις κάνοντας χρήση της `show`.

# %%
f(x) = ((x^2 + 3*x + 2) * (x - 1)) / (x^2 - 4*x + 3) + (3*x^3) / (x^2 + x + 1) - sin(x)
show(f)
f(x,y) = ((x + y)^2 - (x - y)^2) / (x * y + 1) + (x^3 - y^3) / (x - y) + 2 * sin(x * y)
show(f)
# Out:
# x |--> 3*x^3/(x^2 + x + 1) + (x^2 + 3*x + 2)*(x - 1)/(x^2 - 4*x + 3) - sin(x)
# (x, y) |--> ((x + y)^2 - (x - y)^2)/(x*y + 1) + (x^3 - y^3)/(x - y) + 2*sin(x*y)

# %% [markdown]
# # Είσοδος, Έξοδος

# %% [markdown]
# ## Άσκηση

# %% [markdown]
# Κάντε χρήση της `input` ώστε να διαβαστούν οι τιμές δύο αντιστάσεων και να μετατραπούν σε πραγματικό, `float`. Στη συνέχεια υπολογίστε την συνολική αντίσταση στην περίπτωση σύνδεσης σε σειρά και παράλληλα.
#
# Σε σειρά:
# $$ R_{\text{series}} = R_1 + R_2 $$
#
# Παράλληλα:
# $$ \frac{1}{R_{\text{parallel}}} = \frac{1}{R_1} + \frac{1}{R_2} $$
#
# Με κατάλληλη χρήση της `print` εμφανίστε τα αποτελέσματα με τρόπο παρόμοιο με τον επόμενο:
#
# - Αντίσταση R1: 3.5 ohms Αντίσταση R2: 4.3 ohms
#
# - Συνολική αντίσταση σε σύνδεση σε σειρά: 7.8 ohms
#
# - Συνολική αντίσταση σε παράλληλη σύνδεση: 1.9294871794871797 ohms

# %%
R1 = float(input("Δώστε την αντίσταση R1 (σε ohms): "))
R2 = float(input("Δώστε την αντίσταση R2 (σε ohms): "))

RS = R1 + R2

RP = 1 / (1 / R1 + 1 / R2)


print('Αντίσταση R1:',R1,'ohms Αντίσταση R2:',R2,'ohms')
print('Συνολική αντίσταση σε σύνδεση σε σειρά:',RS,'ohms')
print('Συνολική αντίσταση σε παράλληλη σύνδεση:',RP,'ohms')
# Out:
# Δώστε την αντίσταση R1 (σε ohms):  3.5
# Δώστε την αντίσταση R2 (σε ohms):  4.3
# Αντίσταση R1: 3.5 ohms Αντίσταση R2: 4.3 ohms
# Συνολική αντίσταση σε σύνδεση σε σειρά: 7.8 ohms
# Συνολική αντίσταση σε παράλληλη σύνδεση: 1.9294871794871797 ohms

# %% [markdown]
# ## Άσκηση

# %% [markdown]
# Κάντε χρήση της `input` ώστε να διαβαστεί φυσικός αριθμός n. Στην συνέχεια εμφανίστε με τη βοήθεια της δομής `for` και της `print` τους αριθμούς 1, 2, ..., n ως εξής:
#
# - Δώσε φυσικό αριθμό n:5
#
# - 0->1->2->3->4->5

# %%
n = int(input('Δώσε φυσικό αριθμό n:'))
for i in range(n): print(i,end="->")
print(n)
# Out:
# Δώσε φυσικό αριθμό n: 5
# 0->1->2->3->4->5
