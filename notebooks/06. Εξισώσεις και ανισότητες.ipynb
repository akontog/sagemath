# %% [markdown]
# <div style="padding: 20px 0; text-align: center; font-weight: bold; font-size: 170%; background-color: #1d4055; color: #ffffff;"> 06. Εξισώσεις και ανισότητες</div>

# %% [markdown]
# Η `solve` αποτελεί την βασική συνάρτηση επίλυσης εξισώσεων

# %%
solve( cot(x)==0, x )
# Out:
# [x == 1/2*pi]

# %% [markdown]
# Σε περίπτωση που έχουμε σύστημα εξισώσεων απαιτούνται παράμετροι για κάθε άγνωστο.

# %%
var('y')
solve ([2* x - y ==3 , x +4* y == -2] , x , y)
# Out:
# [[x == (10/9), y == (-7/9)]]

# %%
import sympy as sp
