# %% [markdown]
# <div style="padding: 20px 0; text-align: center; font-weight: bold; font-size: 170%; background-color: #1d4055; color: #ffffff;"> Εργασία 03. Λογισμός</div>

# %% [markdown]
# # Άσκηση

# %% [markdown]
# Σχεδιάστε την γραφική παράσταση της επόμενης συνάρτησης ορίζοντάς την ως δίκλαδη με την `piecewise`.
# $$
# f(x) =
# \begin{cases}
# x^2 & \text{if } x \leq 1 \\
# \frac{1}{x} & \text{if } x > 1
# \end{cases}
# $$

# %% [markdown]
# ## Λύση

# %% [markdown]
# # Άσκηση

# %% [markdown]
# Να διερευνηθεί το όριο:
# $$
# \lim_{x \to 0} \frac{\tan(x)}{|x|}
# $$
# Σχεδιάστε την γραφική παράσταση της αντίστοιχης συνάρτησης.

# %% [markdown]
# ## Λύση

# %% [markdown]
# # Άσκηση

# %% [markdown]
# 1. Δημιουργήστε τη συνάρτηση:
# $$
# f(x) = x^2 + 3x - 4
# $$
#
# 2. Υπολογίστε τις ρίζες της εξίσωσης f(x) = 0.
#
# 3. Επαληθεύστε τις λύσεις εισάγοντας τις στη συνάρτηση  για να δείτε αν επιστρέφει μηδέν.
#
# 4. Υπολογίστε την παράγωγο.
#
# 5. Βρείτε το αόριστο ολοκλήρωμα.
#
# 5. Βρείτε το ολοκλήρωμα στο [2, 3]
#
# 6. Σχεδιάστε την γραφική παράσταση από το -5 έως το 5

# %% [markdown]
# ## Λύση

# %% [markdown]
# # Άσκηση

# %% [markdown]
# Σχεδιάστε την γραφική παράσταση και βρείτε τα ακρότατα της επόμενης συνάρτησης:
# $$
# f(x) = x \ln{x}, x>0
# $$

# %% [markdown]
# ## Λύση

# %% [markdown]
# # Άσκηση

# %% [markdown]
# Έστω οι συναρτήσεις
# $$
# f(x)= x^2 - 6x+10
# $$
#
# $$
# g(x)=-x^2 + 6x
# $$
#
# 1. Βρείτε τα σημεία τομής είτε κάνοντας πράξεις είτε με τη βοήθεια της solve
#
# 2. Σχεδιάστε τη γραφική παράστασή τους βάζοντας χρώμα στο χωρίο ανάμεσα.
#
# 3. Βρείτε το εμβαδόν του χωρίου

# %% [markdown]
# ## Λύση
